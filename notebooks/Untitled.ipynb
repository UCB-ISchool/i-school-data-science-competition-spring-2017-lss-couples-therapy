# %%
import pickle
import pandas as pd

# %%
with open('objs.pickle', 'rb') as f:
    divorce_data = pickle.load(f)

divorce_headers = ["Name", "MarriageDates", "FirstMarriageDate", "DivorceDates", "MarriageLengths", "AverageMarriageLengths"]
    

divorce_df = pd.DataFrame(divorce_data, columns=divorce_headers)
print(len(divorce_df.index))
divorce_df.head()

# divorce_df.to_csv("../data/processed/divorce_dates.csv")
# Out:
# 11749
#                         Name MarriageDates  FirstMarriageDate DivorceDates  \
# 0              Rixa of Werle            []                NaN           []
# 1                 Riyaz Khan            []                NaN           []
# 2            Rizwanur Rahman            []                NaN           []
# 3                 Roald Dahl  [1953, 1983]             1953.0       [1983]
# 4  Rob Ackerman (playwright)            []                NaN           []
#
#   MarriageLengths  AverageMarriageLengths
# 0              []                     NaN
# 1              []                     NaN
# 2              []                     NaN
# 3            [30]                    30.0
# 4              []                     NaN

# %%
divorce_df.describe()
# Out:
# /home/sayan/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        FirstMarriageDate  AverageMarriageLengths
# count        1970.000000              572.000000
# mean         1967.520812                9.554991
# std            70.249738                7.575783
# min          1137.000000               -7.500000
# 25%                  NaN                     NaN
# 50%                  NaN                     NaN
# 75%                  NaN                     NaN
# max          2017.000000               46.000000

# %%
divorce_df.columns = ["Name", "MarriageDates", "FirstMarriageDate", "DivorceDates", "MarriageLengths", "AverageMarriageLengths"]

# %%
# divorce_df["NumMarriages"] = divorce_df["MarriageDates"].map(len)
# divorce_df[divorce_df['Name'].str.contains('Elizabeth T', na=False)]
divorce_df.sort(["NumMarriages"], ascending=False).head(50)
# Out:
# /home/sayan/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                                         Name  \
# 4368                           Zsa Zsa Gabor
# 87                   Robert Evans (producer)
# 4534                          Barbara Hutton
# 6619                        Elizabeth Taylor
# 4260              Zayed bin Sultan Al Nahyan
# 934                        Georgia Frontiere
# 8363                            Claude Rains
# 5173                      Billy Bob Thornton
# 6273                     Eleanor Post Hutton
# 984                           Geraldo Rivera
# 3651                             Jane Powell
# 10068                         Katharine Ross
# 2345                          Ingmar Bergman
# 857                           George Peppard
# 9572                        Stavros Niarchos
# 1128                           Ginger Rogers
# ...

# %%
divorce_df[divorce_df.FirstMarriageDate.notnull()].describe()
